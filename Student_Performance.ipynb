# %%
import pandas as pd


df = pd.read_exceldf_excel = pd.read_excel("C:\\Users\\Sujal\\Desktop\\Project\\Excel\\SMDA PRACTICALS\\Practical 1\\data\\cleaned\\Student_Performance_Data_Cleaned.xlsx", sheet_name="Students Performance Dataset")

print("Excel file imported successfully!")
# Out:
# Excel file imported successfully!

# %%
print("\nFirst Five Rows:")
print(df.head())
# Out:
# First Five Rows:
#   Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0      S2894        Ali  Williams  student1894@university.com  Female   21
# 1      S2246       Emma   Johnson  student1246@university.com    Male   22
# 2      S2421        Ali  Williams  student1421@university.com    Male   18
# 3      S3948       Emma     Brown  student2948@university.com    Male   21
# 4      S5593       Liam   Johnson  student4593@university.com    Male   21
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Mathematics          100.00          66.24        67.79  ...
# 1     Business           99.99          59.31        55.23  ...
# 2     Business           99.97          76.07        51.40  ...
# 3  Engineering           99.96          80.12        97.37  ...
# 4  Mathematics           99.95          79.33        71.03  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# ...

# %%
print("\nLast Five Rows:")
print(df.tail())
# Out:
# Last Five Rows:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 4995      S4464      Maria     Brown  student3464@university.com    Male   18
# 4996      S2546       Liam     Brown  student1546@university.com    Male   20
# 4997      S2990      Maria     Brown  student1990@university.com  Female   22
# 4998      S3277       Emma     Jones  student2277@university.com    Male   19
# 4999      S3836       Emma     Jones  student2836@university.com  Female   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 4995  Mathematics           50.04          95.34        67.08  ...
# 4996     Business           50.03          64.28        58.65  ...
# 4997           CS           50.02          45.80        62.39  ...
# 4998  Mathematics           50.02          68.87        52.19  ...
# 4999  Mathematics           50.01          84.88        51.54  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# ...

# %%
print("\nShape of Dataset:")
print(df.shape)
# Out:
# Shape of Dataset:
# (5000, 23)

# %%
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Student_ID', 'First_Name', 'Last_Name', 'Email', 'Gender', 'Age',
#        'Department', 'Attendance (%)', 'Midterm_Score', 'Final_Score',
#        'Assignments_Avg', 'Quizzes_Avg', 'Participation_Score',
#        'Projects_Score', 'Total_Score', 'Grade', 'Study_Hours_per_Week',
#        'Extracurricular_Activities', 'Internet_Access_at_Home',
#        'Parent_Education_Level', 'Family_Income_Level', 'Stress_Level (1-10)',
#        'Sleep_Hours_per_Night'],
#       dtype='object')

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Student_ID                     object
# First_Name                     object
# Last_Name                      object
# Email                          object
# Gender                         object
# Age                             int64
# Department                     object
# Attendance (%)                float64
# Midterm_Score                 float64
# Final_Score                   float64
# Assignments_Avg               float64
# Quizzes_Avg                   float64
# Participation_Score           float64
# Projects_Score                float64
# Total_Score                   float64
# Grade                          object
# Study_Hours_per_Week          float64
# Extracurricular_Activities     object
# Internet_Access_at_Home        object
# Parent_Education_Level         object
# Family_Income_Level            object
# Stress_Level (1-10)             int64
# Sleep_Hours_per_Night         float64
# dtype: object

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Student_ID                    0
# First_Name                    0
# Last_Name                     0
# Email                         0
# Gender                        0
# Age                           0
# Department                    0
# Attendance (%)                0
# Midterm_Score                 0
# Final_Score                   0
# Assignments_Avg               0
# Quizzes_Avg                   0
# Participation_Score           0
# Projects_Score                0
# Total_Score                   0
# Grade                         0
# Study_Hours_per_Week          0
# Extracurricular_Activities    0
# Internet_Access_at_Home       0
# Parent_Education_Level        0
# Family_Income_Level           0
# Stress_Level (1-10)           0
# Sleep_Hours_per_Night         0
# dtype: int64

# %%
sorted_df = df.sort_values(by="Final_Score", ascending=False)

print("\nStudents Sorted by Final Score:")
print(sorted_df)
# Out:
# Students Sorted by Final Score:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 1513      S3688      Ahmed     Brown  student2688@university.com    Male   18
# 3856      S5152       John     Smith  student4152@university.com    Male   22
# 4892      S1957        Ali  Williams   student957@university.com  Female   18
# 1744      S4304       Sara     Davis  student3304@university.com    Male   24
# 4956      S4522      Maria  Williams  student3522@university.com    Male   19
# ...         ...        ...       ...                         ...     ...  ...
# 213       S4226      Ahmed   Johnson  student3226@university.com    Male   23
# 83        S3137       Liam  Williams  student2137@university.com  Female   19
# 2451      S3284       Sara   Johnson  student2284@university.com    Male   23
# 2917      S4139       Omar     Smith  student3139@university.com    Male   22
# 4599      S4516       John     Jones  student3516@university.com    Male   21
#
# ...

# %%
below_75 = df[df["Attendance (%)"] < 75]

print("\nStudents with Attendance Below 75%:")
print(below_75)
# Out:
# Students with Attendance Below 75%:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 2569      S2276        Ali   Johnson  student1276@university.com    Male   24
# 2570      S5735       Omar     Jones  student4735@university.com  Female   21
# 2571      S1832       John     Brown   student832@university.com  Female   23
# 2572      S1946      Ahmed     Davis   student946@university.com    Male   21
# 2573      S2766       Emma  Williams  student1766@university.com    Male   19
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S4464      Maria     Brown  student3464@university.com    Male   18
# 4996      S2546       Liam     Brown  student1546@university.com    Male   20
# 4997      S2990      Maria     Brown  student1990@university.com  Female   22
# 4998      S3277       Emma     Jones  student2277@university.com    Male   19
# ...

# %%
above_80 = df[df["Final_Score"] > 80]

print("\nStudents with Final Score Above 80:")
print(above_80)
# Out:
# Students with Final Score Above 80:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 3         S3948       Emma     Brown  student2948@university.com    Male   21
# 6         S2221       Sara     Davis  student1221@university.com  Female   22
# 7         S3389       Sara     Jones  student2389@university.com    Male   22
# 10        S5943       John  Williams  student4943@university.com    Male   24
# 11        S1226      Ahmed     Smith   student226@university.com    Male   22
# ...         ...        ...       ...                         ...     ...  ...
# 4980      S3933        Ali     Smith  student2933@university.com  Female   18
# 4981      S3247       Omar     Davis  student2247@university.com    Male   23
# 4986      S4450      Maria     Brown  student3450@university.com  Female   18
# 4989      S2619      Ahmed     Smith  student1619@university.com  Female   23
# ...

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#                Age  Attendance (%)  Midterm_Score  Final_Score  \
# count  5000.000000     5000.000000    5000.000000  5000.000000
# mean     21.048400       75.356076      70.701924    69.546552
# std       1.989786       14.392716      17.436325    17.108996
# min      18.000000       50.010000      40.000000    40.010000
# 25%      19.000000       62.945000      55.707500    54.697500
# 50%      21.000000       75.670000      70.860000    69.485000
# 75%      23.000000       87.862500      85.760000    83.922500
# max      24.000000      100.000000      99.990000    99.980000
#
#        Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# count      5000.000000  5000.000000          5000.000000      5000.00000
# mean         74.956320    74.836214            49.963720        74.78305
# std          14.404287    14.423848            28.989785        14.54243
# min          50.000000    50.000000             0.000000        50.00000
# ...
