# %%
import pandas as pd


df = pd.read_exceldf_excel = pd.read_excel("C:\\Users\\Sujal\\Desktop\\Project\\Excel\\SMDA PRACTICALS\\Practical 1\\data\\cleaned\\Supermarket_Sales_Data_Cleaned.xlsx", sheet_name="Supermarket_Sales_1000_Rows")

print("Excel file imported successfully!")
# Out:
# Excel file imported successfully!

# %%
print("\nFirst Five Rows:")
print(df.head())
# Out:
# First Five Rows:
#   Invoice_ID            Branch       City     Product_Line  Unit_Price  \
# 0    INV0001  Bangalore Branch  Bangalore      Electronics    62328.21
# 1    INV0002  Hyderabad Branch  Hyderabad         Clothing     7250.92
# 2    INV0003  Bangalore Branch  Bangalore      Electronics    18968.22
# 3    INV0004       Pune Branch       Pune      Electronics    56129.09
# 4    INV0005     Mumbai Branch     Mumbai  Home Appliances     5139.56
#
#    Quantity  Total_Sales       Date      Payment
# 0         2    124656.42 2026-06-12          UPI
# 1         4     29003.68 2026-01-07   Debit Card
# 2         1     18968.22 2026-09-03          UPI
# 3         2    112258.18 2026-06-16         Cash
# 4         3     15418.68 2026-10-09  Credit Card

# %%
print("\nLast Five Rows:")
print(df.tail())
# Out:
# Last Five Rows:
#     Invoice_ID            Branch       City            Product_Line  \
# 995    INV0996  Hyderabad Branch  Hyderabad  Beauty & Personal Care
# 996    INV0997       Pune Branch       Pune               Groceries
# 997    INV0998     Mumbai Branch     Mumbai               Groceries
# 998    INV0999    Chennai Branch    Chennai  Beauty & Personal Care
# 999    INV1000      Delhi Branch      Delhi                Clothing
#
#      Unit_Price  Quantity  Total_Sales       Date      Payment
# 995      211.60         3       634.80 2026-06-21   Debit Card
# 996      521.41         3      1564.23 2026-12-30         Cash
# 997     2293.30         9     20639.70 2026-05-09  Credit Card
# 998     2783.33         1      2783.33 2026-07-26          UPI
# 999     2410.14         4      9640.56 2026-08-13  Credit Card

# %%
print("\nShape of Dataset:")
print(df.shape)
# Out:
# Shape of Dataset:
# (1000, 9)

# %%
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['Invoice_ID', 'Branch', 'City', 'Product_Line', 'Unit_Price',
#        'Quantity', 'Total_Sales', 'Date', 'Payment'],
#       dtype='object')

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Invoice_ID              object
# Branch                  object
# City                    object
# Product_Line            object
# Unit_Price             float64
# Quantity                 int64
# Total_Sales            float64
# Date            datetime64[ns]
# Payment                 object
# dtype: object

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Invoice_ID      0
# Branch          0
# City            0
# Product_Line    0
# Unit_Price      0
# Quantity        0
# Total_Sales     0
# Date            0
# Payment         0
# dtype: int64

# %%
sorted_df = df.sort_values(by="Invoice_ID", ascending=False)

print("\nDataset Sorted By Transactions:")
print(sorted_df)
# Out:
# Dataset Sorted By Transactions:
#     Invoice_ID            Branch       City            Product_Line  \
# 999    INV1000      Delhi Branch      Delhi                Clothing
# 998    INV0999    Chennai Branch    Chennai  Beauty & Personal Care
# 997    INV0998     Mumbai Branch     Mumbai               Groceries
# 996    INV0997       Pune Branch       Pune               Groceries
# 995    INV0996  Hyderabad Branch  Hyderabad  Beauty & Personal Care
# ..         ...               ...        ...                     ...
# 4      INV0005     Mumbai Branch     Mumbai         Home Appliances
# 3      INV0004       Pune Branch       Pune             Electronics
# 2      INV0003  Bangalore Branch  Bangalore             Electronics
# 1      INV0002  Hyderabad Branch  Hyderabad                Clothing
# 0      INV0001  Bangalore Branch  Bangalore             Electronics
#
#      Unit_Price  Quantity  Total_Sales       Date      Payment
# ...

# %%
city_filter = df[df["City"] == "Mumbai"]

print("\nCity Filter with Mumbai City:")
print(city_filter)
# Out:
# City Filter with Mumbai City:
#     Invoice_ID         Branch    City            Product_Line  Unit_Price  \
# 4      INV0005  Mumbai Branch  Mumbai         Home Appliances     5139.56
# 8      INV0009  Mumbai Branch  Mumbai         Home Appliances     4895.77
# 17     INV0018  Mumbai Branch  Mumbai  Beauty & Personal Care      823.32
# 25     INV0026  Mumbai Branch  Mumbai               Groceries      749.38
# 27     INV0028  Mumbai Branch  Mumbai               Groceries     4305.42
# ..         ...            ...     ...                     ...         ...
# 979    INV0980  Mumbai Branch  Mumbai             Electronics    49164.71
# 984    INV0985  Mumbai Branch  Mumbai         Home Appliances    19231.84
# 987    INV0988  Mumbai Branch  Mumbai         Home Appliances    23870.89
# 993    INV0994  Mumbai Branch  Mumbai             Electronics    24809.15
# 997    INV0998  Mumbai Branch  Mumbai               Groceries     2293.30
#
# ...

# %%
product_filter = df[df["Product_Line"] == "Electronics"]

print("\nProduct_Line Filter with Electronic:")
print(product_filter)
# Out:
# Product_Line Filter with Electronic:
#     Invoice_ID            Branch       City Product_Line  Unit_Price  \
# 0      INV0001  Bangalore Branch  Bangalore  Electronics    62328.21
# 2      INV0003  Bangalore Branch  Bangalore  Electronics    18968.22
# 3      INV0004       Pune Branch       Pune  Electronics    56129.09
# 15     INV0016      Delhi Branch      Delhi  Electronics    53403.68
# 18     INV0019  Bangalore Branch  Bangalore  Electronics    25001.27
# ..         ...               ...        ...          ...         ...
# 975    INV0976       Pune Branch       Pune  Electronics    15811.30
# 979    INV0980     Mumbai Branch     Mumbai  Electronics    49164.71
# 989    INV0990  Bangalore Branch  Bangalore  Electronics    74722.87
# 990    INV0991       Pune Branch       Pune  Electronics    73487.93
# 993    INV0994     Mumbai Branch     Mumbai  Electronics    24809.15
#
#      Quantity  Total_Sales       Date Payment
# 0           2    124656.42 2026-06-12     UPI
# ...

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#          Unit_Price     Quantity    Total_Sales                           Date
# count   1000.000000  1000.000000    1000.000000                           1000
# mean   14905.222200     3.081000   33976.561550  2026-07-01 15:53:16.799999744
# min       53.180000     1.000000      74.680000            2026-01-01 00:00:00
# 25%     3046.015000     2.000000    8193.230000            2026-04-05 00:00:00
# 50%     6607.070000     3.000000   19456.475000            2026-06-26 00:00:00
# 75%    19457.032500     4.000000   42794.302500            2026-09-24 00:00:00
# max    74722.870000    10.000000  222082.200000            2026-12-31 00:00:00
# std    17985.690616     2.066085   40478.290812                            NaN
